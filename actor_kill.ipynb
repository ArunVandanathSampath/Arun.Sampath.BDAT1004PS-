# %% [markdown]
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name. Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('actor_kill_counts.csv')

# Sort the data by kill count
df = df.sort_values('Count', ascending=False)

# Create a horizontal bar chart
fig, ax = plt.subplots()
ax.barh(df['Actor'], df['Count'], align='center', color='red')

# Add labels and title
ax.set_xlabel('Kill Count')
ax.set_ylabel('Actor')
ax.set_title('Deadliest Actors in Hollywood')

# Invert the y-axis to show highest at the top
ax.invert_yaxis()

# Display the plot
plt.show()
